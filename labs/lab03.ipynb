# %%
# %matplotlib inline
from datascience import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
drought = Table.read_table("drought.csv")

# %%
drought.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Week</th> <th>None</th> <th>D0</th> <th>D1</th> <th>D2</th> <th>D3</th> <th>D4</th> <th>DSCI</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2023-01-17</td> <td>0.07</td> <td>6.74</td> <td>72.94</td> <td>20.25</td> <td>0    </td> <td>0   </td> <td>234 </td>
#         </tr>
#         <tr>
#             <td>2023-01-10</td> <td>0   </td> <td>0.87</td> <td>71.51</td> <td>27.61</td> <td>0.01 </td> <td>0   </td> <td>242 </td>
#         </tr>
#         <tr>
#             <td>2023-01-03</td> <td>0   </td> <td>0.52</td> <td>43.52</td> <td>37.92</td> <td>18.04</td> <td>0   </td> <td>296 </td>
#         </tr>
#         <tr>
#             <td>2022-12-27</td> <td>0   </td> <td>0.52</td> <td>30.78</td> <td>43.52</td> <td>21.84</td> <td>3.34</td> <td>321 </td>
#         </tr>
#         <tr>
# ...

# %%
drought.where("D0", are.below(20)).num_rows / drought.num_rows
# Out:
# 1.0

# %%
drought.column("D0") - drought.column("D4")
# Out:
# array([ 6.74,  0.87,  0.52, -2.82, -2.82, -2.82, -6.44, -6.44, -6.44, -6.44])

# %%
worst_weeks = drought.where("D3", are.above(10))
dsci_ww = worst_weeks.sort("DSCI").column("Week")
dsci_ww
# Out:
# array(['2023-01-03', '2022-12-27', '2022-12-20', '2022-12-13',
#        '2022-12-06', '2022-11-29', '2022-11-22', '2022-11-15'],
#       dtype='<U10')

# %%
staff = Table.read_table("staff.csv")

# %%
good_staff = staff.where("Hearts per Post", are.above(0)).where("Admin", True)
luck_staff_name = good_staff.sort("Answers").column("Name").item(0)

# %%
luck_staff_name
# Out:
# 'Atticus Ginsborg'
