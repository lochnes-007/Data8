# %%
# %pip install otter-grader==5.5.0
# %cd /content/gdrive/MyDrive/colab-materials-data8-notebooks/materials-sp22-colab/hw/hw04/

# Initialize Otter
import otter
grader = otter.Notebook(colab=True)
# Out:
# Requirement already satisfied: otter-grader==5.5.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (5.5.0)
# Requirement already satisfied: jinja2 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (3.1.6)
# Requirement already satisfied: nbconvert in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (7.17.1)
# Requirement already satisfied: click in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (8.1.8)
# Requirement already satisfied: fica>=0.3.1 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (0.4.1)
# Requirement already satisfied: ipylab in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (1.1.0)
# Requirement already satisfied: ipython in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (8.18.1)
# Requirement already satisfied: PyYAML in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (6.0.3)
# Requirement already satisfied: python-on-whales in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (0.81.0)
# Requirement already satisfied: ipywidgets in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (8.1.8)
# Requirement already satisfied: requests in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (2.32.5)
# Requirement already satisfied: nbformat in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (5.10.4)
# Requirement already satisfied: wrapt in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (2.3.0)
# Requirement already satisfied: astunparse in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (1.6.3)
# Requirement already satisfied: dill in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (0.4.1)
# Requirement already satisfied: pandas in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (2.3.3)
# Requirement already satisfied: jupytext in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from otter-grader==5.5.0) (1.19.5)
# Requirement already satisfied: sphinx in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from fica>=0.3.1->otter-grader==5.5.0) (7.4.7)
# Requirement already satisfied: docutils in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from fica>=0.3.1->otter-grader==5.5.0) (0.21.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from astunparse->otter-grader==5.5.0) (0.48.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from astunparse->otter-grader==5.5.0) (1.17.0)
# Requirement already satisfied: packaging>=24.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from wheel<1.0,>=0.23.0->astunparse->otter-grader==5.5.0) (26.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipywidgets->otter-grader==5.5.0) (4.0.15)
# Requirement already satisfied: comm>=0.1.3 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipywidgets->otter-grader==5.5.0) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipywidgets->otter-grader==5.5.0) (5.15.1)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipywidgets->otter-grader==5.5.0) (3.0.16)
# Requirement already satisfied: matplotlib-inline in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipython->otter-grader==5.5.0) (0.2.2)
# Requirement already satisfied: typing-extensions in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipython->otter-grader==5.5.0) (4.16.0)
# Requirement already satisfied: decorator in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipython->otter-grader==5.5.0) (5.3.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipython->otter-grader==5.5.0) (3.0.52)
# Requirement already satisfied: pexpect>4.3 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipython->otter-grader==5.5.0) (4.9.0)
# Requirement already satisfied: exceptiongroup in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipython->otter-grader==5.5.0) (1.3.1)
# Requirement already satisfied: stack-data in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipython->otter-grader==5.5.0) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipython->otter-grader==5.5.0) (2.20.0)
# Requirement already satisfied: jedi>=0.16 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from ipython->otter-grader==5.5.0) (0.19.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython->otter-grader==5.5.0) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython->otter-grader==5.5.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->otter-grader==5.5.0) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jinja2->otter-grader==5.5.0) (3.0.3)
# Requirement already satisfied: tomli in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jupytext->otter-grader==5.5.0) (2.4.1)
# Requirement already satisfied: markdown-it-py>=1.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jupytext->otter-grader==5.5.0) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jupytext->otter-grader==5.5.0) (0.4.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from markdown-it-py>=1.0->jupytext->otter-grader==5.5.0) (0.1.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbconvert->otter-grader==5.5.0) (8.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbconvert->otter-grader==5.5.0) (5.8.1)
# Requirement already satisfied: defusedxml in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbconvert->otter-grader==5.5.0) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbconvert->otter-grader==5.5.0) (4.15.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbconvert->otter-grader==5.5.0) (0.10.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbconvert->otter-grader==5.5.0) (3.3.4)
# Requirement already satisfied: bleach[css]!=5.0.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbconvert->otter-grader==5.5.0) (6.2.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbconvert->otter-grader==5.5.0) (0.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbconvert->otter-grader==5.5.0) (1.5.1)
# Requirement already satisfied: webencodings in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert->otter-grader==5.5.0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert->otter-grader==5.5.0) (1.4.0)
# Requirement already satisfied: zipp>=3.20 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from importlib-metadata>=3.6->nbconvert->otter-grader==5.5.0) (3.23.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jupyter-core>=4.7->nbconvert->otter-grader==5.5.0) (4.4.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbclient>=0.5.0->nbconvert->otter-grader==5.5.0) (8.6.3)
# Requirement already satisfied: tornado>=6.2 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->otter-grader==5.5.0) (6.5.8)
# Requirement already satisfied: pyzmq>=23.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->otter-grader==5.5.0) (27.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->otter-grader==5.5.0) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbformat->otter-grader==5.5.0) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from nbformat->otter-grader==5.5.0) (4.25.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->otter-grader==5.5.0) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->otter-grader==5.5.0) (0.27.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->otter-grader==5.5.0) (0.36.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->otter-grader==5.5.0) (26.1.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->otter-grader==5.5.0) (2.8.4)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from pandas->otter-grader==5.5.0) (2026.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from pandas->otter-grader==5.5.0) (2026.3.post1)
# Requirement already satisfied: numpy>=1.22.4 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from pandas->otter-grader==5.5.0) (2.0.2)
# Requirement already satisfied: pydantic!=2.0.*,<3,>=2 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from python-on-whales->otter-grader==5.5.0) (2.13.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales->otter-grader==5.5.0) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales->otter-grader==5.5.0) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales->otter-grader==5.5.0) (2.46.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from requests->otter-grader==5.5.0) (2026.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from requests->otter-grader==5.5.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from requests->otter-grader==5.5.0) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from requests->otter-grader==5.5.0) (3.5.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (2.0.0)
# Requirement already satisfied: alabaster~=0.7.14 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (0.7.16)
# Requirement already satisfied: sphinxcontrib-qthelp in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (2.0.0)
# Requirement already satisfied: babel>=2.13 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (2.18.0)
# Requirement already satisfied: imagesize>=1.3 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (1.5.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (3.1.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from sphinx->fica>=0.3.1->otter-grader==5.5.0) (1.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from stack-data->ipython->otter-grader==5.5.0) (3.0.2)
# Requirement already satisfied: pure-eval in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from stack-data->ipython->otter-grader==5.5.0) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages (from stack-data->ipython->otter-grader==5.5.0) (2.2.1)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/ayushthasale07/Sarg<3/Data8/.venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/colab-materials-data8-notebooks/materials-sp22-colab/hw/hw04/'
# /Users/ayushthasale07/Sarg<3/Data8/homwork/hw04

# %% [markdown]
# # Homework 4: Functions, Tables, and Groups
#
# Please complete this notebook by filling in the cells provided. Before you begin, execute the previous cell to load the provided tests.

# %% [markdown]
# **Helpful Resource:**
# - [Python Reference](http://data8.org/sp22/python-reference.html): Cheat sheet of helpful array & table methods used in Data 8!
#
# **Recommended Readings**:
#
# * [Visualizing Numerical Distributions](https://www.inferentialthinking.com/chapters/07/2/Visualizing_Numerical_Distributions.html)
# * [Functions and Tables](https://www.inferentialthinking.com/chapters/08/Functions_and_Tables.html)

# %% [markdown]
# Please complete this notebook by filling in the cells provided. Before you begin, execute the following cell to setup the notebook by importing some helpful libraries. Each time you start your server, you will need to execute this cell again.
#
# For all problems that you must write explanations and sentences for, you **must** provide your answer in the designated space. **Moreover, throughout this homework and all future ones, please be sure to not re-assign variables throughout the notebook!** For example, if you use `max_temperature` in your answer to one question, do not reassign it later on. Otherwise, you will fail tests that you thought you were passing previously!
#
#
# **Note: This homework has hidden tests on it. That means even though the tests may say 100% passed, it doesn't mean your final grade will be 100%. We will be running more tests for correctness once everyone turns in the homework.**
#
#
# Directly sharing answers is not okay, but discussing problems with the course staff or with other students is encouraged.
#
# You should start early so that you have time to get help if you're stuck.

# %% [markdown]
# ## 1. Burrito-ful San Diego

# %%
# Run this cell to set up the notebook, but please don't change it.

# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import warnings
warnings.simplefilter('ignore', FutureWarning)
warnings.filterwarnings("ignore")

# %% [markdown]
# Mira, Sofia, and Sara are trying to use Data Science to find the best burritos in San Diego! Their friends Jessica and Sonya provided them with two comprehensive datasets on many burrito establishments in the San Diego area taken from (and cleaned from): https://www.kaggle.com/srcole/burritos-in-san-diego/data

# %% [markdown]
# The following cell reads in a table called `ratings` which contains names of burrito restaurants, their Yelp rating, Google rating, as well as their overall rating. The `Overall` rating is not an average of the `Yelp` and `Google` ratings, but rather it is the overall rating of the customers that were surveyed in the study above.
#
#
# It also reads in a table called `burritos_types` which contains names of burrito restaurants, their menu items, and the cost of the respective menu item at the restaurant.

# %%
# Just run this cell
ratings = Table.read_table("ratings.csv")
ratings.show(5)
burritos_types = Table.read_table("burritos_types.csv").drop(0)
burritos_types.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Yelp</th> <th>Google</th> <th>Overall</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Albertacos                </td> <td>3.5 </td> <td>3.9   </td> <td>3.45   </td>
#         </tr>
#         <tr>
#             <td>Burrito Factory           </td> <td>4.5 </td> <td>4.8   </td> <td>3.5    </td>
#         </tr>
#         <tr>
#             <td>Burros and Fries          </td> <td>3.5 </td> <td>4.1   </td> <td>3.575  </td>
#         </tr>
#         <tr>
#             <td>Caliente Mexican Food     </td> <td>3.5 </td> <td>4.4   </td> <td>3.25   </td>
#         </tr>
#         <tr>
#             <td>California Burrito Company</td> <td>3.5 </td> <td>4.4   </td> <td>3.2    </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (77 rows omitted)</p>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Menu_Item</th> <th>Cost</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Albertacos                                         </td> <td>California          </td> <td>5.7 </td>
#         </tr>
#         <tr>
#             <td>Albertacos                                         </td> <td>Carne Asada         </td> <td>5.25</td>
#         </tr>
#         <tr>
#             <td>Alberto's 623 N Escondido Blvd, Escondido, CA 92025</td> <td>Carne Asada         </td> <td>4.59</td>
#         </tr>
#         <tr>
#             <td>Burrito Box                                        </td> <td>Steak With Guacamole</td> <td>11.5</td>
#         </tr>
#         <tr>
#             <td>Burrito Factory                                    </td> <td>Steak Everything    </td> <td>7.35</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (244 rows omitted)</p>

# %% [markdown]
# **Question 1.** It would be easier if we could combine the information in both tables. Assign `burritos` to the result of joining the two tables together, so that we have a table with the ratings for every corresponding menu item from every restaurant. Each menu item has the same rating as the restaurant from which it is from. **(8 Points)**
#
# *Note:* It doesn't matter which table you put in as the argument to the table method, either order will work for the autograder tests.
#
# *Hint:* If you need help on using the `join` method, refer to the [Python Reference Sheet](http://data8.org/sp22/python-reference.html) or [Section 8.4](https://www.inferentialthinking.com/chapters/08/4/Joining_Tables_by_Columns.html) in the textbook.

# %%
burritos = burritos_types.join("Name", ratings)
burritos.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Menu_Item</th> <th>Cost</th> <th>Yelp</th> <th>Google</th> <th>Overall</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Albertacos      </td> <td>California      </td> <td>5.7 </td> <td>3.5 </td> <td>3.9   </td> <td>3.45   </td>
#         </tr>
#         <tr>
#             <td>Albertacos      </td> <td>Carne Asada     </td> <td>5.25</td> <td>3.5 </td> <td>3.9   </td> <td>3.45   </td>
#         </tr>
#         <tr>
#             <td>Burrito Factory </td> <td>Steak Everything</td> <td>7.35</td> <td>4.5 </td> <td>4.8   </td> <td>3.5    </td>
#         </tr>
#         <tr>
#             <td>Burros and Fries</td> <td>California      </td> <td>7.19</td> <td>3.5 </td> <td>4.1   </td> <td>3.575  </td>
#         </tr>
#         <tr>
#             <td>Burros and Fries</td> <td>Carne Asada     </td> <td>6.89</td> <td>3.5 </td> <td>4.1   </td> <td>3.575  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (207 rows omitted)</p>

# %%
grader.check("q1_1")
# Out:
# q1_1 results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 2.** Let's look at how the Yelp scores compare to the Google scores in the `burritos` table. First, assign `yelp_and_google` to a table only containing the columns `Yelp` and `Google`. Then, make a scatter plot with Yelp scores on the x-axis and the Google scores on the y-axis. **(8 Points)**

# %%
yelp_and_google = burritos.select("Yelp", "Google")
yelp_and_google.scatter("Yelp")

# Don't change/edit/remove the following line.
# To help you make conclusions, we have plotted a straight line on the graph (y=x).
plt.plot(np.arange(2.5,5,.5), np.arange(2.5,5,.5));

# %%
grader.check("q1_2")
# Out:
# q1_2 results: All test cases passed!

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **Question 3.** Looking at the scatter plot you just made in Question 1.2, do you notice any pattern(s) (i.e. is one of the two types of scores consistently higher than the other one)? If so, describe them **briefly** in the cell below. **(8 Points)**

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# Here's a refresher on how `.group` works! You can read how `.group` works in the [textbook](https://www.inferentialthinking.com/chapters/08/2/Classifying_by_One_Variable.html), or you can view the video below. The video resource was made by a past staff member, Divyesh Chotai!
#
# You can also use the [Table Functions Visualizer](http://data8.org/interactive_table_functions/) to get some more hands-on experience with the `.group` function.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("HLoYTCUP0fc")

# %% [markdown]
# **Question 4.** There are so many types of California burritos in the `burritos` table! Sara wants to know which type is the highest rated across all restaurants. For the sake of these questions, we are treating each menu item's rating the same as its respective restaurant's, as we do not have the rating of every single item at these restaurants. You do not need to worry about this fact, but we thought to mention it!
#
# Create a table with two columns: the first column include the names of the burritos and the second column should contain the average overall rating of that burrito across restaurants. **In your calculations, you should only compare burritos that contain the word "California".** For example, there are "California" burritos, "California Breakfast" burritos, "California Surf And Turf" burritos, etc. **(9 Points)**
#
# *Hint:* If multiple restaurants serve the "California - Chicken" burrito, what table method can we use to aggregate those together and find the average overall rating?
#
# *Note:* For reference, the staff solution only used one line. However, feel free to break up the solution into multiple lines and steps; just make sure you assign the final output table to `california_burritos`!

# %%
cal_burs = burritos.where("Menu_Item", are.containing("California"))
def burr_mean(x, y):
    return np.mean(np.array(x, y))
california_burritos = Table().with_columns(
    "Name", cal_burs.column("Menu_Item"),
    "Average Rating", cal_burs.apply(burr_mean, "Yelp", "Google")
    )
california_burritos = california_burritos.group("Name", collect=np.mean)
california_burritos
# Out:
# Name                           | Average Rating mean
# California                     | 3.83704
# California (Only Cheese)       | 4.5
# California + Guac + Sour Cream | 4
# California - Chicken           | 3.75
# California - Pork Adobada      | 3.5
# California - Steak             | 3.5
# California Breakfast           | 3
# California Chicken             | 4
# California Chipotle            | 4
# California Everything          | 4.5
# ... (9 rows omitted)

# %%
grader.check("q1_4")
# Out:
# q1_4 results: All test cases passed!

# %% [markdown]
# **Question 5.** Given this new table `california_burritos`, Sara can figure out the name of the California burrito with the highest overall average rating! Assign `best_california_burrito` to a line of code that outputs the string that represents the name of the California burrito with the highest overall average rating. If multiple burritos satisfy this criteria, you can output any one of them. **(8 Points)**

# %%
best_california_burrito = str(california_burritos.sort("Average Rating mean", descending=True).take(0).column("Name").take(0))
best_california_burrito
# Out:
# 'California (Only Cheese)'

# %%
grader.check("q1_5")
# Out:
# q1_5 results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 6.** Mira thinks that burritos in San Diego are cheaper (and taste better) than the burritos in Berkeley. Plot a histogram that visualizes that distribution of the costs of the burritos from San Diego in the `burritos` table. Also use the provided `bins` variable when making your histogram, so that the histogram is more visually informative. **(8 Points)**

# %%
bins = np.arange(0, 15, 1)
# Please also use the provided bins
burritos.hist("Cost", bins=bins)

# %% [markdown]
# <!-- END QUESTION -->
#
# **Question 7.** What percentage of burritos in San Diego are less than $6? Assign `burritos_less_than_6` to your answer, which should be between 0 and 100. You should only use the histogram above to answer the question. Do not use code on the table to to find the answer, just eyeball the heights and use Python to evaluate your arithmetic! **(8 Points)**
#
# *Note*: Your answer does not have to be exact, but it should be within a couple percentages of the staff answer.

# %%
burritos_less_than_6 = (burritos.where("Cost", are.below(6)).num_rows / burritos.num_rows)*100
burritos_less_than_6
# Out:
# 22.641509433962266

# %%
grader.check("q1_7")
# Out:
# q1_7 results: All test cases passed!

# %% [markdown]
# ## 2. San Francisco City Employee Salaries

# %% [markdown]
# This exercise is designed to give you practice with using the Table methods `.pivot` and `.group`. Here is a link to the [Python Reference Sheet](http://data8.org/sp22/python-reference.html) in case you need a quick refresher. The [Table Function Visualizer](http://data8.org/interactive_table_functions/) may also be a helpful tool.
#
# Run the cell below to view a demo on how you can use pivot on a table. (Thank you to past staff Divyesh Chotai!)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("4WzXo8eKLAg")

# %% [markdown]
# The data source we will use within this portion of the homework is [publicly provided](https://data.sfgov.org/City-Management-and-Ethics/Employee-Compensation/88g8-5mnd/data) by the City of San Francisco. We have filtered it to retain just the relevant columns and restricted the data to the calendar year 2019. Run the following cell to load our data into a table called `full_sf`.

# %%
full_sf = Table.read_table("sf2019.csv")
full_sf.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Organization Group</th> <th>Department</th> <th>Job Family</th> <th>Job</th> <th>Salary</th> <th>Overtime</th> <th>Benefits</th> <th>Total Compensation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Public Protection </td> <td>Adult Probation</td> <td>Information Systems</td> <td>IS Trainer-Journey           </td> <td>91332 </td> <td>0       </td> <td>40059   </td> <td>131391            </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Adult Probation</td> <td>Information Systems</td> <td>IS Engineer-Assistant        </td> <td>123241</td> <td>0       </td> <td>49279   </td> <td>172520            </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Adult Probation</td> <td>Information Systems</td> <td>IS Business Analyst-Senior   </td> <td>115715</td> <td>0       </td> <td>46752   </td> <td>162468            </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Adult Probation</td> <td>Information Systems</td> <td>IS Business Analyst-Principal</td> <td>159394</td> <td>0       </td> <td>57312   </td> <td>216706            </td>
#         </tr>
#         <tr>
#             <td>Public Protection </td> <td>Adult Probation</td> <td>Information Systems</td> <td>IS Programmer Analyst        </td> <td>70035 </td> <td>0       </td> <td>28671   </td> <td>98706             </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (44520 rows omitted)</p>

# %% [markdown]
# The table has one row for each of the 44,525 San Francisco government employees in 2019.
#
# The first four columns describe the employee's job. For example, the employee in the third row of the table had a job called "IS Business Analyst-Senior". We will call this the employee's *position* or *job title*. The job was in a Job Family called Information Systems (hence the IS in the job title), and was in the Adult Probation Department that is part of the Public Protection Organization Group of the government. You will mostly be working with the `Job` column.
#
# The next three columns contain the dollar amounts paid to the employee in the calendar year 2019 for salary, overtime, and benefits. Note that an employee’s salary does not include their overtime earnings.
#
# The last column contains the total compensation paid to the employee. It is the sum of the previous three columns:
#
# $$\text{Total Compensation} = \text{Salary} + \text{Overtime} + \text{Benefits}$$
#
# For this homework, we will be using the following columns:
# 1. `Organization Group`: A group of departments. For example, the **Public Protection** Org. Group includes departments such as the Police, Fire, Adult Protection, District Attorney, etc.
# 2. `Department`: The primary organizational unit used by the City and County of San Francisco.
# 3. `Job`: The specific position that a given worker fills.
# 4. `Total Compensation`: The sum of a worker's salary, overtime, and benefits in 2019.
#
#
# Run the following cell to select the relevant columns and create a new table named `sf`.

# %%
sf = full_sf.select("Job", "Department", "Organization Group",  "Total Compensation")
sf.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Job</th> <th>Department</th> <th>Organization Group</th> <th>Total Compensation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>IS Trainer-Journey           </td> <td>Adult Probation</td> <td>Public Protection </td> <td>131391            </td>
#         </tr>
#         <tr>
#             <td>IS Engineer-Assistant        </td> <td>Adult Probation</td> <td>Public Protection </td> <td>172520            </td>
#         </tr>
#         <tr>
#             <td>IS Business Analyst-Senior   </td> <td>Adult Probation</td> <td>Public Protection </td> <td>162468            </td>
#         </tr>
#         <tr>
#             <td>IS Business Analyst-Principal</td> <td>Adult Probation</td> <td>Public Protection </td> <td>216706            </td>
#         </tr>
#         <tr>
#             <td>IS Programmer Analyst        </td> <td>Adult Probation</td> <td>Public Protection </td> <td>98706             </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (44520 rows omitted)</p>

# %% [markdown]
# We want to use this table to generate arrays with the job titles of the members of each **Organization Group**.

# %% [markdown]
# **Question 1.** Set `job_titles` to a table with two columns. The first column should be called `Organization Group` and have the name of every "Organization Group" once, and the second column should be called `Jobs` with each row in that second column containing an *array* of the names of all the job titles within that "Organization Group". Don't worry if there are multiple of the same job titles. **(9 Points)**
#
# *Hint:* Think about how `group` works: it collects values into an array and then applies a function to that array. We have defined two functions below for you, and you will need to use one of them in your call to `group`.

# %%
# Pick one of the two functions defined below in your call to group.
def first_item(array):
    '''Returns the first item'''
    return array.item(0)

def full_array(array):
    '''Returns the array that is passed through'''
    return array 

# Make a call to group using one of the functions above when you define job_titles
job_titles = sf.select("Organization Group", "Job").group("Organization Group",collect=full_array).relabeled("Job full_array", "Jobs")
job_titles
# Out:
# Organization Group                       | Jobs
# Community Health                         | ['Painter Supervisor 1' 'Painter' 'Painter' ..., 'Nursin ...
# Culture & Recreation                     | ['Electrician' 'Executive Secretary 2' 'Bldgs & Grounds  ...
# General Administration & Finance         | ['Painter' 'Painter' 'Electrician' ..., 'Investigator, T ...
# Human Welfare & Neighborhood Development | ['Dept Head I' 'Administrative Analyst' 'Community Devel ...
# Public Protection                        | ['IS Trainer-Journey' 'IS Engineer-Assistant' 'IS Busine ...
# Public Works, Transportation & Commerce  | ['Heavy Equip Ops Asst Sprv' 'Heavy Equipment Ops Sprv'
#  ...

# %%
grader.check("q2_1")
# Out:
# q2_1 results: All test cases passed!

# %% [markdown]
# #### Understanding the code you just wrote in 2.1 is important for moving forward with the class! If you made a lucky guess, take some time to look at the code, step by step. Office hours is always a great resource!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 2.** At the moment, the `Job` column of the `sf` table is not sorted (no particular order). Would the arrays you generated in the `Jobs` column of the previous question be the same if we had sorted alphabetically instead before generating them? Explain your answer. To receive full credit, your answer should reference *how* the `.group` method works, and how sorting the `Jobs` column would affect this.  **(8 Points)**
#
# *Note:* Two arrays are the **same** if they contain the same number of elements and the elements located at corresponding indexes in the two arrays are identical. An example of arrays that are NOT the same: `array([1,2]) != array([2,1])`.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# **Question 3.** Set `department_ranges` to a table containing departments as the rows, and the organization groups as the columns. The values in the rows should correspond to a total compensation range, where range is defined as the **difference between the highest total compensation and the lowest total compensation in the department for that organization group**. **(9 Points)**
#
# *Hint 1:* First you'll need to define a new function `compensation_range` which takes in an array of compensations and returns the range of compensations in that array.
#
# *Hint 2:* What table function allows you to specify the rows and columns of a new table? You probably watched a video on it earlier in the homework!

# %%
sf.show(5)
# clean_sf.group("")
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Job</th> <th>Department</th> <th>Organization Group</th> <th>Total Compensation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>IS Trainer-Journey           </td> <td>Adult Probation</td> <td>Public Protection </td> <td>131391            </td>
#         </tr>
#         <tr>
#             <td>IS Engineer-Assistant        </td> <td>Adult Probation</td> <td>Public Protection </td> <td>172520            </td>
#         </tr>
#         <tr>
#             <td>IS Business Analyst-Senior   </td> <td>Adult Probation</td> <td>Public Protection </td> <td>162468            </td>
#         </tr>
#         <tr>
#             <td>IS Business Analyst-Principal</td> <td>Adult Probation</td> <td>Public Protection </td> <td>216706            </td>
#         </tr>
#         <tr>
#             <td>IS Programmer Analyst        </td> <td>Adult Probation</td> <td>Public Protection </td> <td>98706             </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (44520 rows omitted)</p>

# %%
# Define compensation_range first
def compensation_range(arr):
    return np.max(arr) - np.min(arr)

clean_sf = sf.select("Department", "Organization Group", "Total Compensation")
department_ranges = clean_sf.pivot( "Organization Group", "Department","Total Compensation", compensation_range)
department_ranges
# clean_sf.group([ "Organization Group","Department"])
# Out:
# Department              | Community Health | Culture & Recreation | General Administration & Finance | Human Welfare & Neighborhood Development | Public Protection | Public Works, Transportation & Commerce
# Academy Of Sciences     | 0                | 199121               | 0                                | 0                                        | 0                 | 0
# Administrative Services | 0                | 0                    | 478784                           | 0                                        | 0                 | 0
# Adult Probation         | 0                | 0                    | 0                                | 0                                        | 303419            | 0
# Airport Commission      | 0                | 0                    | 0                                | 0                                        | 0                 | 445092
# Art Commission          | 0                | 251823               | 0                                | 0                                        | 0                 | 0
# Asian Art Museum        | 0                | 298230               | 0                                | 0                                        | 0                 | 0
# Assessor                | 0                | 0                    | 277385                           | 0                                        | 0                 | 0
# Board Of Appeals        | 0                | 0                    | 0                                | 0                                        | 0                 | 243582
# Board Of Supervisors    | 0                | 0                    | 293773                           | 0                                        | 0                 | 0
# Building Inspection     | 0                | 0                    | 0                                | 0                                        | 0                 | 340852
# ... (41 rows omitted)

# %%
grader.check("q2_3")
# Out:
# q2_3 results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 4.** Give an explanation as to why some of the row values are `0` in the `department_ranges` table from the previous question. **(8 Points)**

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# **Question 5.** Find the number of departments appearing in the `sf` table that have an average total compensation of greater than 125,000 dollars; assign this value to the variable `num_over_125k`. **(9 Points)**
#
# *Hint:* The variable names provided are meant to help guide the intermediate steps and general thought process. Feel free to delete them if you'd prefer to start from scratch, but make sure your final answer is assigned to `num_over_125k`!

# %%
sf.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Job</th> <th>Department</th> <th>Organization Group</th> <th>Total Compensation</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>IS Trainer-Journey           </td> <td>Adult Probation</td> <td>Public Protection </td> <td>131391            </td>
#         </tr>
#         <tr>
#             <td>IS Engineer-Assistant        </td> <td>Adult Probation</td> <td>Public Protection </td> <td>172520            </td>
#         </tr>
#         <tr>
#             <td>IS Business Analyst-Senior   </td> <td>Adult Probation</td> <td>Public Protection </td> <td>162468            </td>
#         </tr>
#         <tr>
#             <td>IS Business Analyst-Principal</td> <td>Adult Probation</td> <td>Public Protection </td> <td>216706            </td>
#         </tr>
#         <tr>
#             <td>IS Programmer Analyst        </td> <td>Adult Probation</td> <td>Public Protection </td> <td>98706             </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (44520 rows omitted)</p>

# %%
depts_and_comp = sf.select("Department", "Total Compensation")
avg_of_depts = depts_and_comp.group("Department", collect=np.mean)
num_over_125k = avg_of_depts.where("Total Compensation mean", are.above(125_000)).num_rows
num_over_125k
# Out:
# 23

# %%
grader.check("q2_5")
# Out:
# q2_5 results: All test cases passed!

# %% [markdown]
# You're done with Homework 4!
#
# **Important submission steps:**
# 1. Run the tests and verify that they all pass.
# 2. Choose **Save Notebook** from the **File** menu, then **run the final cell**.
# 3. Click the link to download the zip file.
# 4. Then submit the zip file to the corresponding assignment according to your instructor's directions.
#
# **It is your responsibility to make sure your work is saved before running the last cell.**

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
# grader.export(run_tests=True)
