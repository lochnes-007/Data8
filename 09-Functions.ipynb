# %%
from datascience import *
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# /Users/ayushthasale07/Sarg<3/Data8/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
top_movies = Table.read_table("top_movies_2017.csv")
top_movies.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Title</th> <th>Studio</th> <th>Gross</th> <th>Gross (Adjusted)</th> <th>Year</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Gone with the Wind         </td> <td>MGM      </td> <td>198676459</td> <td>1796176700      </td> <td>1939</td>
#         </tr>
#         <tr>
#             <td>Star Wars                  </td> <td>Fox      </td> <td>460998007</td> <td>1583483200      </td> <td>1977</td>
#         </tr>
#         <tr>
#             <td>The Sound of Music         </td> <td>Fox      </td> <td>158671368</td> <td>1266072700      </td> <td>1965</td>
#         </tr>
#         <tr>
#             <td>E.T.: The Extra-Terrestrial</td> <td>Universal</td> <td>435110554</td> <td>1261085000      </td> <td>1982</td>
#         </tr>
#         <tr>
#             <td>Titanic                    </td> <td>Paramount</td> <td>658672302</td> <td>1204368000      </td> <td>1997</td>
# ...

# %%
ages = 2026 - top_movies.column("Year")
top_movies = top_movies.with_column("Age", ages)
top_movies.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Title</th> <th>Studio</th> <th>Gross</th> <th>Gross (Adjusted)</th> <th>Year</th> <th>Age</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Gone with the Wind         </td> <td>MGM      </td> <td>198676459</td> <td>1796176700      </td> <td>1939</td> <td>87  </td>
#         </tr>
#         <tr>
#             <td>Star Wars                  </td> <td>Fox      </td> <td>460998007</td> <td>1583483200      </td> <td>1977</td> <td>49  </td>
#         </tr>
#         <tr>
#             <td>The Sound of Music         </td> <td>Fox      </td> <td>158671368</td> <td>1266072700      </td> <td>1965</td> <td>61  </td>
#         </tr>
#         <tr>
#             <td>E.T.: The Extra-Terrestrial</td> <td>Universal</td> <td>435110554</td> <td>1261085000      </td> <td>1982</td> <td>44  </td>
#         </tr>
#         <tr>
# ...

# %%
my_bins = np.array([0, 5, 10, 15, 20, 25, 40, 65, 105])

# %%
binned_data = top_movies.bin("Age", bins=my_bins)
binned_data
# Out:
# bin  | Age count
# 0    | 0
# 5    | 3
# 10   | 25
# 15   | 18
# 20   | 21
# 25   | 47
# 40   | 59
# 65   | 27
# 105  | 0

# %%
top_movies.hist("Age", bins=np.arange(0, 120, 10))

# %%
survey = Table.read_table("welcome_survey_sp22.csv")
survey.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>Extroversion</th> <th>Number of textees</th> <th>Hours of sleep</th> <th>Handedness</th> <th>Pant leg</th> <th>Sleep position</th> <th>Pets</th> <th>Piercings</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Second</td> <td>5           </td> <td>5                </td> <td>8             </td> <td>Left-handed </td> <td>Left leg in first </td> <td>On your left side </td> <td>Ants                          </td> <td>0        </td>
#         </tr>
#         <tr>
#             <td>Fourth</td> <td>2           </td> <td>3                </td> <td>7             </td> <td>Right-handed</td> <td>Left leg in first </td> <td>On your left side </td> <td>Beetles, Centipedes, Scorpions</td> <td>0        </td>
#         </tr>
#         <tr>
# ...

# %%
handedness = survey.group("Handedness")

# %%
handedness.barh("Handedness")

# %%
sleep_pos = survey.group("Sleep position")
sleep_pos.barh("Sleep position")
# sleep_pos

# %%
survey.scatter("Extroversion", "Number of textees")
plt.ylim(0, 20)
# Out:
# (0.0, 20.0)

# %%
def perc(values):
    return values  / 100

sleep_pos.apply(perc, "count")
# Out:
# array([ 3.16,  3.46,  4.85,  1.96])
